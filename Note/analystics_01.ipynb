# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
import platform

if platform.system() == "Darwin":   # macOS
    plt.rcParams["font.family"] = "AppleGothic"
else:                               # Windows / Linux
    plt.rcParams["font.family"] = "Malgun Gothic"

plt.rcParams["axes.unicode_minus"] = False

# %%
API_KEY = "6b73525368726573343358656d6346"

# %%
import sys
# !{sys.executable} -m pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.2-cp314-cp314-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Downloading lxml-6.0.2-cp314-cp314-macosx_10_13_universal2.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 2.7 MB/s  0:00:03 eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2

# %%
url = f"http://openapi.seoul.go.kr:8088/{API_KEY}/xml/SpotInfo/1/5/"
data = pd.read_xml(url)
data
# Out:
#    list_total_count      CODE     MESSAGE spot_num      spot_nm  grs80tm_x  \
# 0             139.0       NaN         NaN      NaN          NaN        NaN
# 1               NaN  INFO-000  정상 처리되었습니다      NaN          NaN        NaN
# 2               NaN       NaN         NaN     B-32  올림픽대로(개화IC)   183484.0
# 3               NaN       NaN         NaN     C-02        월드컵대교   189882.0
# 4               NaN       NaN         NaN     F-01        올림픽대로   197646.0
# 5               NaN       NaN         NaN     F-02         강변북로   197729.0
# 6               NaN       NaN         NaN     F-05       동부간선도로   207000.0
#
#    grs80tm_y
# 0        NaN
# 1        NaN
# 2   454270.0
# 3   450789.0
# 4   445188.0
# 5   446395.0
# 6   452742.0
